# %%
df= pd.read_csv(r'C:\Users\Daniel\project university\Выпускная работа\Сlean.csv')
df
# Out:
#           id             rooms     cost(₽)  square(м²)  cost_for_meter(₽)  \
# 0          0    1 – комнатная    5000000.0        31.0          161290.30
# 1          1        1 комната    4500000.0        98.0           45918.40
# 2          2    1 – комнатная   10900000.0        36.1          301939.10
# 3          3        1 комната    3650000.0        93.0           39247.30
# 4          4       доля (1/2)    1200000.0        72.3           16597.50
# ...      ...               ...         ...         ...                ...
# 88700  88710  3-комн. квартира   8231888.0        58.4          140957.28
# 88701  88711  3-комн. квартира  16407663.5        74.8          219353.98
# 88702  88712  2-комн. квартира   9203120.0        53.9          170744.14
# 88703  88713  1-комн. квартира   7182400.0        30.7          233954.62
# 88704  88714  1-комн. квартира   7281714.1        35.3          206280.94
#
#                                         address                metro_name  \
# ...

# %%
duplicateRows = df[df.duplicated ()]

# %%
duplicateRows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 0 non-null      int64
#  1   rooms              0 non-null      object
#  2   cost(₽)            0 non-null      float64
#  3   square(м²)         0 non-null      float64
#  4   cost_for_meter(₽)  0 non-null      float64
#  5   address            0 non-null      object
#  6   metro_name         0 non-null      object
#  7   distance(м)        0 non-null      float64
#  8   center_distance/m  0 non-null      float64
#  9   floor              0 non-null      int64
#  10  floors             0 non-null      int64
#  11  description        0 non-null      object
# dtypes: float64(5), int64(3), object(4)
# memory usage: 0.0+ bytes

# %%
import pandas as pd
df= pd.read_csv(r'C:\Users\Daniel\project university\Выпускная работа\DataSet\Недвижка\my_DS\moscow_full_2.0.csv')
df

# %%
duplicateRows = df[df.duplicated ()]

# %%
duplicateRows

# %%
df= pd.read_csv(r'C:\Users\Daniel\project university\Выпускная работа\DataSet\Недвижка\my_DS\Realty.csv')

# %%
df

# %%
duplicateRows = df[df.duplicated ()]

# %%
duplicateRows
# Out:
#                    rooms       cost(₽)  square(м²)  cost_for_meter(₽)  \
# 1425      1 – комнатная   1.950000e+07        50.3          387674.00
# 1435      1 – комнатная   1.175000e+07        30.0          391666.70
# 1919      2 – комнатная   2.200000e+07        50.0          440000.00
# 2772      3 – комнатная   2.350000e+07        56.2          418149.50
# 4187      5 – комнатная   3.500000e+08       280.3         1248662.10
# ...                  ...           ...         ...                ...
# 100385  1-комн. квартира  9.270699e+06        32.1          288806.18
# 100421  1-комн. квартира  9.330704e+06        32.1          290675.48
# 100423  2-комн. квартира  1.235534e+07        51.8          238520.00
# 100514  1-комн. квартира  8.978559e+06        32.2          278836.58
# 100547  1-комн. квартира  8.740659e+06        32.1          272294.70
#
#                                                 address         metro_name  \
# ...

# %%
df= pd.read_csv(r'C:\Users\Daniel\project university\Выпускная работа\Сlean.csv')

# %%
df.loc[[9348,31218,30637,9778,64439,82414,189,8263,2316,21498]]
# Out:
#           id             rooms     cost(₽)  square(м²)  cost_for_meter(₽)  \
# 9348    9348    4 – комнатная   26500000.0       102.8          257782.10
# 31218  31220    4 – комнатная   26500000.0       102.8          257782.10
# 30637  30639    2 – комнатная   15000000.0        58.0          258620.70
# 9778    9778    2 – комнатная   15000000.0        58.0          258620.70
# 64439  64446  3-комн. квартира  14445200.0        65.0          222233.64
# 82414  82423  2-комн. квартира  14070000.0        65.0          216460.92
# 189      189    2 – комнатная    5650000.0        38.0          148684.20
# 8263    8263    1 – комнатная    9900000.0        34.9          283667.60
# 2316    2316    1 – комнатная    6950000.0        22.0          315909.10
# 21498  21499    2 – комнатная    9900000.0        44.0          225000.00
#
#                                   address              metro_name  \
# 9348                     Полярная ул., 32              медведково
# ...

# %%
[(9348, 0.10472742291355852),
 (31218, 0.21939642880236143),
 (30637, 0.40788023442797106),
 (9778, 0.4404129975619282),
 (64439, 0.4609256349286014),
 (82414, 0.47658541882369687),
 (189, 0.4893587492222151),
 (8263, 0.4946403195926775),
 (2316, 0.4985172572553872),
 (21498, 0.4985623437176312)]
