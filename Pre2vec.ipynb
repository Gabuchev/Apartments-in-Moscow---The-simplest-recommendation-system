# %%
import re  # For preprocessing
# !pip install pandas
import pandas as pd  # For data handling
from time import time  # To time our operations
import spacy
from spacy.lang.ru.examples import sentences 
from collections import defaultdict  # For word frequency
import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)
# Out:
# Requirement already satisfied: pandas in c:\users\daniel\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\daniel\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\daniel\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\daniel\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\daniel\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)

# %%
data = pd.read_csv('Сlean.csv')
df=data['description']
df.shape
# Out:
# (100723,)

# %%
df.head()
# Out:
# 0    Прекрасная однокомнатная квартира в доме с лиф...
# 1    Светлая, просторная комната 19 кв. метров. Отд...
# 2    Первомайская, 15 мин. пешкомТёплая уютная квар...
# 3    в шаговой доступности парк Сокольники. , Разви...
# 4    Ильинское с.Все коммуникации центральные.Кварт...
# Name: description, dtype: object

# %%
df.isnull().sum()
# Out:
# 0

# %%
# !python -m spacy download ru_core_news_sm
# Out:
# Collecting ru-core-news-sm==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.3.0/ru_core_news_sm-3.3.0-py3-none-any.whl (15.3 MB)
#      ---------------------------------------- 15.3/15.3 MB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: pymorphy2>=0.9 in c:\users\daniel\anaconda3\lib\site-packages (from ru-core-news-sm==3.3.0) (0.9.1)
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in c:\users\daniel\anaconda3\lib\site-packages (from ru-core-news-sm==3.3.0) (3.3.1)
# Requirement already satisfied: dawg-python>=0.7.1 in c:\users\daniel\anaconda3\lib\site-packages (from pymorphy2>=0.9->ru-core-news-sm==3.3.0) (0.7.2)
# Requirement already satisfied: docopt>=0.6 in c:\users\daniel\anaconda3\lib\site-packages (from pymorphy2>=0.9->ru-core-news-sm==3.3.0) (0.6.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in c:\users\daniel\anaconda3\lib\site-packages (from pymorphy2>=0.9->ru-core-news-sm==3.3.0) (2.4.417127.4579844)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.3.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.21.5)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.0.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (21.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.4.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.8.2)
# Requirement already satisfied: jinja2 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.11.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.4.2)
# Requirement already satisfied: setuptools in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (63.4.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.0.8)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (8.0.15)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.7.7)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.7.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (4.64.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.0.10)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.28.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.10.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\daniel\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\users\daniel\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\daniel\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (4.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\daniel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\daniel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\daniel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\daniel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2022.9.14)
# Requirement already satisfied: colorama in c:\users\daniel\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.4.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\daniel\appdata\roaming\python\python39\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (8.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\daniel\anaconda3\lib\site-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)

# %%
nlp = spacy.load('ru_core_news_sm', disable=['ner', 'parser']) # disabling Named Entity Recognition for speed
def cleaning(doc):
    # Lemmatizes and removes stopwords
    # doc needs to be a spacy Doc object
    txt = [token.lemma_ for token in doc if not token.is_stop]
    # Word2Vec uses context words to learn the vector representation of a target word,
    # if a sentence is only one or two words long,
    # the benefit for the training is very small
    if len(txt) > 2:
        return ' '.join(txt)
# Out:
# INFO - 01:25:39: Loading dictionaries from c:\Users\Daniel\anaconda3\lib\site-packages\pymorphy2_dicts_ru\data
# INFO - 01:25:39: format: 2.4, revision: 417127, updated: 2020-10-11T15:05:51.070345

# %%
brief_cleaning = (re.sub("[^А-Яа-я]", ' ', str(row)).lower() for row in data['description'])

# %%
t = time()

#txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=5000, n_process=-1)]
txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=2000, n_process=4)]
print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 26.03 mins

# %%
df_clean = pd.DataFrame({'clean': txt})
df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
# Out:
# (65113, 1)

# %%
df_clean.head(20)
# Out:
#                                                 clean
# 0   прекрасный однокомнатный квартира дом лифт мус...
# 1   светлый   просторный комната     кв   метр   о...
# 2   первомайский      мина   пешкомт плая уютный к...
# 3   шаговый доступность парк сокольники     развит...
# 4   ильинский коммуникация центральный квартира хо...
# 5   продаваться срочно однокомнатный квартира ремо...
# 6   знамя октябрь пос продаваться светлый   уютный...
# 7   маяковская      мина   пешкомбаррикадная      ...
# 8   продаваться двухкомнатный квартира общий площа...
# 9   домодедово успейте купить выгодно             ...
# 10      хороший вариант инвестирование   возможнос...
# 11  обухово рппродается комната     кв ул   яковле...
# 12    срочно продажа малогабаритный     комн кварт...
# 13    дом построить   квартира сделать ремонт ингр...
# 14  продаваться    кв ра       бывший общежитие   ...
# 15  продаваться двухкомнатный квартира высокий пер...
# 16  элитный жк новый измайлово   закрытый территор...
# 17  продаваться просмотр   продаваться      доля  ...
# 18  пятницкое       мина   транспортомпросторная к...
# 19  видный квартира   отличный   состояние      ко...

# %%
df_clean.to_csv('PRE.csv',index=True)

# %%
from gensim.models.phrases import Phrases, Phraser

# %%
sent = [row.split() for row in df_clean['clean']]

# %%
phrases = Phrases(sent, min_count=30, progress_per=10000)
# Out:
# INFO - 01:56:15: collecting all words and their counts
# INFO - 01:56:15: PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO - 01:56:16: PROGRESS: at sentence #10000, processed 623358 words and 173825 word types
# INFO - 01:56:17: PROGRESS: at sentence #20000, processed 1187655 words and 273413 word types
# INFO - 01:56:18: PROGRESS: at sentence #30000, processed 1733814 words and 343709 word types
# INFO - 01:56:20: PROGRESS: at sentence #40000, processed 2866897 words and 443755 word types
# INFO - 01:56:22: PROGRESS: at sentence #50000, processed 3884567 words and 528139 word types
# INFO - 01:56:23: PROGRESS: at sentence #60000, processed 4895880 words and 598383 word types
# INFO - 01:56:24: collected 635089 token types (unigram + bigrams) from a corpus of 5313725 words and 65113 sentences
# INFO - 01:56:24: merged Phrases<635089 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>
# INFO - 01:56:24: Phrases lifecycle event {'msg': 'built Phrases<635089 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000> in 8.72s', 'datetime': '2022-11-17T01:56:24.570894', 'gensim': '4.2.0', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'created'}

# %%
bigram = Phraser(phrases)
# Out:
# INFO - 01:56:27: exporting phrases from Phrases<635089 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>
# INFO - 01:56:29: FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<3862 phrases, min_count=30, threshold=10.0> from Phrases<635089 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000> in 2.09s', 'datetime': '2022-11-17T01:56:29.456241', 'gensim': '4.2.0', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'created'}

# %%
sentences = bigram[sent]

# %%
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
len(word_freq)
# Out:
# 46478

# %%
sorted(word_freq, key=word_freq.get, reverse=True)[:10]
# Out:
# ['квартира',
#  'дом',
#  'кв',
#  'этаж',
#  'двор',
#  'район',
#  'школа',
#  'комплекс',
#  'жилой',
#  'кухня']

# %%
import multiprocessing
from gensim.models import Word2Vec

# %%
cores = multiprocessing.cpu_count() # Количество ядер на компе

# %%
w2v_model = Word2Vec(min_count=20,
                     window=2,
                     vector_size=300,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)
# Out:
# INFO - 01:58:33: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=0, vector_size=300, alpha=0.03>', 'datetime': '2022-11-17T01:58:33.119629', 'gensim': '4.2.0', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'created'}

# %%
t = time()

w2v_model.build_vocab(sentences, progress_per=10000)

print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# INFO - 01:58:46: collecting all words and their counts
# INFO - 01:58:46: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 01:58:47: PROGRESS: at sentence #10000, processed 519503 words, keeping 17344 word types
# INFO - 01:58:48: PROGRESS: at sentence #20000, processed 990655 words, keeping 23260 word types
# INFO - 01:58:49: PROGRESS: at sentence #30000, processed 1449491 words, keeping 27016 word types
# INFO - 01:58:50: PROGRESS: at sentence #40000, processed 2315237 words, keeping 34080 word types
# INFO - 01:58:52: PROGRESS: at sentence #50000, processed 3117085 words, keeping 39644 word types
# INFO - 01:58:53: PROGRESS: at sentence #60000, processed 3902562 words, keeping 44006 word types
# INFO - 01:58:53: collected 46478 word types from a corpus of 4245081 raw words and 65113 sentences
# INFO - 01:58:53: Creating a fresh vocabulary
# INFO - 01:58:54: Word2Vec lifecycle event {'msg': 'effective_min_count=20 retains 9666 unique words (20.80% of original 46478, drops 36812)', 'datetime': '2022-11-17T01:58:54.052109', 'gensim': '4.2.0', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'prepare_vocab'}
# INFO - 01:58:54: Word2Vec lifecycle event {'msg': 'effective_min_count=20 leaves 4129298 word corpus (97.27% of original 4245081, drops 115783)', 'datetime': '2022-11-17T01:58:54.053107', 'gensim': '4.2.0', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'prepare_vocab'}
# INFO - 01:58:54: deleting the raw counts dictionary of 46478 items
# INFO - 01:58:54: sample=6e-05 downsamples 862 most-common words
# INFO - 01:58:54: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1920945.4989813692 word corpus (46.5%% of prior 4129298)', 'datetime': '2022-11-17T01:58:54.160114', 'gensim': '4.2.0', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'prepare_vocab'}
# INFO - 01:58:54: estimated required memory for 9666 words and 300 dimensions: 28031400 bytes
# INFO - 01:58:54: resetting layer weights
# INFO - 01:58:54: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-11-17T01:58:54.346358', 'gensim': '4.2.0', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'build_vocab'}
# Time to build vocab: 0.12 mins

# %%
w2v_model.init_sims(replace=True)
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_3464\514372312.py:1: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#   w2v_model.init_sims(replace=True)
# WARNING - 01:59:11: destructive init_sims(replace=True) deprecated & no longer required for space-efficiency

# %%
#Наиболее похожие слова на:
w2v_model.wv.most_similar(positive=["добираться"])
# Out:
# [('лавка', 0.2105065882205963),
#  ('рублёво', 0.20606811344623566),
#  ('красный_пресня', 0.20458590984344482),
#  ('воспользоваться_программа', 0.20423823595046997),
#  ('развивающемся', 0.19505524635314941),
#  ('сложный', 0.19070512056350708),
#  ('плюсы', 0.1820734292268753),
#  ('рекордный_ипотека', 0.17914734780788422),
#  ('приятный', 0.17847347259521484),
#  ('единый_пространство', 0.1768987625837326)]

# %%
#Сходство слов
w2v_model.wv.similarity("дом", 'год',)
# Out:
# 0.08323367

# %%
#Лишнее слово
w2v_model.wv.doesnt_match(['квартира', 'кухня', 'метро'])
# Out:
# 'метро'

# %%
#Значимость слов 
w2v_model.wv.most_similar(positive=['этаж', 'квартира'], negative=['школа'], topn=3)
# Out:
# [('клиент', 0.20758584141731262),
#  ('окн', 0.2021651715040207),
#  ('популярный', 0.20012113451957703)]

# %%
w2v_model.wv.index_to_key
# Out:
# ['квартира',
#  'дом',
#  'кв',
#  'этаж',
#  'двор',
#  'район',
#  'школа',
#  'комплекс',
#  'жилой',
#  'кухня',
#  'москва',
#  'ремонт',
#  'метро',
#  'два',
#  'детский_сад',
#  'парк',
#  'жк',
#  'комната',
#  'детский',
#  'окно',
#  'отделка',
#  'новый',
#  'просторный',
#  'находиться',
#  'год',
#  'минута',
#  'продаваться',
#  'корпус',
#  'хороший',
#  'сделка',
#  'шаговый_доступность',
#  'территория',
#  'станция_метро',
#  'инфраструктура',
#  'центр',
#  'магазин',
#  'студия',
#  'площадь',
#  'санузел',
#  'комнатный',
#  'квартал',
#  'продажа',
#  'площадка',
#  'свободный_продажа',
#  'взрослый_собственник',
#  'общий_площадь',
#  'отличный',
#  'минута_пешком',
#  'собственник',
#  'зона',
#  'современный',
#  'больший',
#  'место',
#  'ипотека',
#  'планировка',
#  'поликлиника',
#  'пеший_доступность',
#  'уютный',
#  'вид',
#  'лоджия',
#  'светлый',
#  'подъезд',
#  'подземный_паркинг',
#  'спальня',
#  'расположен',
#  'отдых',
#  'балкон',
#  'собственность',
#  'гостиная',
#  'окно_выходить',
#  'развитой_инфраструктура',
#  'высота_потолок',
#  'сторона',
#  'бизнес_класс',
#  'сделать',
#  'большой',
#  'машина',
#  'полный_стоимость',
#  'первый',
#  'торговый_центр',
#  'предлагаться',
#  'город',
#  'тихий',
#  'мебель',
#  'км',
#  'кредитование_первоначальный',
#  'спортивный',
#  'парковка',
#  'удобный',
#  'метр',
#  'гардеробный',
#  'кафе',
#  'аптека',
#  'транспортный_доступность',
#  'прекрасный',
#  'высокий',
#  'лифт',
#  'иметься',
#  'прода_тся',
#  'свободный',
#  'установить',
#  'станция',
#  'три',
#  'договор',
#  'проект',
#  'банк',
#  'мина',
#  'апартамент',
#  'оперативный_показ',
#  'состояние',
#  'улица',
#  'спортивный_площадка',
#  'быстрый_выход',
#  'расположены',
#  'выполнить',
#  'объект',
#  'зелёный',
#  'транспорт',
#  'т',
#  'возможный',
#  'качественный',
#  'расположена',
#  'этаж_этажный',
#  'вариант',
#  'застройщик',
#  'собственный',
#  'благоустроенный',
#  'комната_изолировать',
#  'минута_ходьба',
#  'дизайнерский',
#  'грузовой_лифт',
#  'двухкомнатный',
#  'раздельный',
#  'однокомнатный',
#  'договор_долевой',
#  'река',
#  'оборудовать',
#  'комфортный',
#  'магазины',
#  'паркинг',
#  'начало_строительство',
#  'год_оформление',
#  'жизнь',
#  'фитнес',
#  'строительство_квартал',
#  'год_окончание',
#  'кирпичный',
#  'цена',
#  'обременение',
#  'высота',
#  'просмотр',
#  'чистый',
#  'звоните',
#  'необходимый',
#  'кухня_столовая',
#  'пол',
#  'бассейн',
#  'дкп',
#  'изолировать',
#  'документ',
#  'развить_инфраструктура',
#  'внутренний',
#  'техника',
#  'первоначальный_взнос',
#  'прокшино',
#  'банк_втб',
#  'престижный',
#  'подъезд_пассажирский',
#  'чистый_подъезд',
#  'консьерж',
#  'прогулка',
#  'коридор',
#  'тёплый',
#  'тц',
#  'пруд',
#  'мина_пешком',
#  'большой_выбор',
#  'красивый',
#  'комн',
#  'ребёнок',
#  'высокий_потолок',
#  'расстояние_прямой',
#  'удобный_транспортный',
#  'банк_сбербанк',
#  'военный_ипотека',
#  'прописать',
#  'часть',
#  'ипотечный_программа',
#  'ресторан',
#  'предусмотреть',
#  'построить',
#  'звоните_подобрать',
#  'база_застройщик',
#  'взнос_срок',
#  'взнос_аккредитация',
#  'государственный_поддержка',
#  'ао_альф',
#  'год_платёж',
#  'ао_россельхозбанк',
#  'программа_срок',
#  'документ_популярный',
#  'россия_пао',
#  'участие_артикул',
#  'сосед',
#  'перепланировка',
#  'выход',
#  'пространство',
#  'ст',
#  'стена',
#  'фитнес_клуб',
#  'доступность',
#  'удобный_выезд',
#  'уникальный',
#  'дверь',
#  'км_мкад',
#  'сад',
#  'входной_группа',
#  'монолитный',
#  'отдельный',
#  'показ',
#  'взрослый',
#  'раздельный_санузел',
#  'московский_прописка',
#  'расположение',
#  'предложение',
#  'проживание',
#  'находиться_секция',
#  'плитка',
#  'торг',
#  'готовый',
#  'сдать',
#  'закрытый',
#  'ваш',
#  'холл',
#  'скидка',
#  'работать',
#  'располагаться',
#  'полный',
#  'салон_красота',
#  'исторический',
#  'уровень',
#  'год_постройка',
#  'житель',
#  'система',
#  'панорамный',
#  'подземный',
#  'входной_дверь',
#  'мебель_техника',
#  'ванный_комната',
#  'салоны_красота',
#  'прямой',
#  'монолитно_блочный',
#  'видеонаблюдение',
#  'столица',
#  'каждый',
#  'набережная',
#  'кондиционер',
#  'здание',
#  'филат_луг',
#  'возможность',
#  'панорамный_вид',
#  'установить_стеклопакет',
#  'вс',
#  'видовой',
#  'автомобиль',
#  'дизайн_проект',
#  'продам',
#  'шоссе',
#  'время',
#  'полностью',
#  'продавать',
#  'быстрый',
#  'мкад',
#  'оставаться',
#  'выходить',
#  'прихожая',
#  'шикарный',
#  'материал',
#  'множество',
#  'помещение',
#  'завести_коммуникация',
#  'дорога',
#  'кафе_ресторан',
#  'встроенная',
#  'сетевой_магазин',
#  'бытовой_техника',
#  'жк_скандинавия',
#  'московский',
#  'ул',
#  'парковочный_место',
#  'сквер',
#  'делать',
#  'панельный',
#  'экологически_чистый',
#  'лоджия_совмещенный',
#  'лес',
#  'ваш_внимание',
#  'мцд',
#  'секция',
#  'стиль',
#  'подходить_ипотека',
#  'шлагбаум',
#  'белый_ночь',
#  'включать',
#  'гостиный',
#  'остановка_общественный',
#  'банка',
#  'цена_указать',
#  'стоимость',
#  'москва_сити',
#  'компания',
#  'покупка',
#  'лесопарк',
#  'закрыть',
#  'гостевой',
#  'остановка',
#  'вход',
#  'супермаркет',
#  'огромный',
#  'повысить_тепло',
#  'потолок',
#  'функциональный_планировка',
#  'покупатель',
#  'безопасность',
#  'аренда',
#  'распашонка',
#  'выезд',
#  'кухонный_зона',
#  'жить',
#  'автобус',
#  'румянцево',
#  'общественный_транспорт',
#  'прокшино_км',
#  'альтернатива',
#  'капитальный_ремонт',
#  'охрана',
#  'продуктовый_магазин',
#  'идеальный',
#  'городской',
#  'потолки',
#  'открываться',
#  'ключ',
#  'бизнес',
#  'вода',
#  'спорт',
#  'входить',
#  'совмещенный_санузел',
#  'комфорт',
#  'переменный_этажность',
#  'комфортный_проживание',
#  'старт_продажа',
#  'полностью_готовый',
#  'рассказать',
#  'преимущество',
#  'трехкомнатная',
#  'огородить',
#  'внутри',
#  'центральный',
#  'мин',
#  'дорогой',
#  'сан_узел',
#  'гостевой_парковка',
#  'ттк',
#  'фасад',
#  'индивидуальный',
#  'позволять',
#  'прописка',
#  'второй',
#  'документ_готовый',
#  'живописный',
#  'лот',
#  'косметический_ремонт',
#  'элитный',
#  'сантехника',
#  'набережный',
#  'встроить',
#  'пять',
#  'совместить',
#  'садовый_кольцо',
#  'крупный',
#  'строиться',
#  'круглосуточный_охрана',
#  'супермаркеты',
#  'близкий',
#  'семья',
#  'окружение',
#  'доступ',
#  'безопасный',
#  'подробно_рассказать',
#  'договор_купля',
#  'капитал',
#  'оформление',
#  'садик',
#  'спальный',
#  'жильё',
#  'юридический_сопровождение',
#  'разместиться',
#  'пешком',
#  'наличный_расчёт',
#  'телефон',
#  'наличие',
#  'арт',
#  'панорамный_остекление',
#  'бульвар',
#  'юго_запад',
#  'сдача',
#  'участие',
#  'подходить',
#  'строительство',
#  'комфортный_жизнь',
#  'услуга',
#  'медицинский_центр',
#  'учёт_скидка',
#  'фото',
#  'жк_испанский',
#  'адрес',
#  'дизайн',
#  'свежий',
#  'некрасовка',
#  'пластиковый_окно',
#  'общий',
#  'являться',
#  'дополнительный',
#  'кинотеатр',
#  'спокойный',
#  'непосредственный_близость',
#  'зарегистрировать',
#  'шкаф',
#  'небольшой',
#  'въезд',
#  'купить',
#  'бронирование_день',
#  'торговый',
#  'комфорт_класс',
#  'стеклопакет',
#  'тихий_зелёный',
#  'этажность_этаж',
#  'число',
#  'гардероб',
#  'полный_юридический',
#  'клуб',
#  'огороженная_территория',
#  'социальный',
#  'клубный',
#  'вопрос',
#  'состоять',
#  'башня',
#  'гимназия',
#  'удобный_время',
#  'день',
#  'изолированный_комната',
#  'чистовой_отделка',
#  'автобусный_остановка',
#  'предлагать',
#  'недвижимость',
#  'наземный',
#  'зал',
#  'тёплый_стан',
#  'различный',
#  'премиум_класс',
#  'обеспечивать',
#  'рынок',
#  'день_просмотр',
#  'класс',
#  'площадь_ильич',
#  'игровой_площадка',
#  'кабинет',
#  'округ',
#  'полноценный',
#  'локация',
#  'премиальный',
#  'прогулочный_зона',
#  'внимание',
#  'терраса',
#  'кремль',
#  'элемент_отопление',
#  'т_плый',
#  'евроремонт',
#  'ванна',
#  'застекленная_лоджия',
#  'шумоизоляцией_установить',
#  'новый_скоростной',
#  'наземный_паркинг',
#  'итальянский',
#  'использовать',
#  'парковый_зона',
#  'тёплый_пол',
#  'угловой',
#  'выполнить_качественный',
#  'микрорайон',
#  'коммуникация',
#  'ост_тся',
#  'серия',
#  'мин_пешком',
#  'оснастить',
#  'стадион',
#  'стильный',
#  'приятный',
#  'менеджер_рассказать',
#  'придомовый_территория',
#  'открыть',
#  'ваш_старый',
#  'сдача_аренда',
#  'выбрать_новый',
#  'больница',
#  'номер_лот',
#  'воздух',
#  'решение',
#  'уходить',
#  'прямо',
#  'авто',
#  'монолитно_кирпичный',
#  'добраться',
#  'пассажирский',
#  'ландшафтный_дизайн',
#  'возле',
#  'новостройка',
#  'открытый',
#  'пол_ламинат',
#  'оформить',
#  'приватизация',
#  'жилец',
#  'человек',
#  'срок_сдача',
#  'создать',
#  'мцк',
#  'помощь_одобрение',
#  'воспользоваться_программа',
#  'информация_телефон',
#  'дерево',
#  'близость',
#  'охранять',
#  'разный',
#  'обустроить',
#  'организовать',
#  'развитой',
#  'выгодный',
#  'европейский',
#  'кладовые_помещение',
#  'этажный',
#  'учёт',
#  'мгу',
#  'специальный_условие',
#  'охранять_территория',
#  'интерьер',
#  'кухонный_гарнитур',
#  'ламинат',
#  'получить',
#  'безопасность_сделка',
#  'частный',
#  'минута_езда',
#  'саларьево_тёплый',
#  'встроить_шкаф',
#  'развить',
#  'стан_ольховая',
#  'мебель_бытовой',
#  'озеро',
#  'сбербанк',
#  'замечательный',
#  'посмотреть_фотография',
#  'объединить',
#  'требовать',
#  'содействие_получение',
#  'ночь',
#  'театр',
#  'бутовский_лесопарк',
#  'позволить',
#  'звоните_прямо',
#  'помощь',
#  'мфц',
#  'полный_сумма',
#  'холодильник',
#  'инвестиция',
#  'шумоизоляцией',
#  'линия',
#  'сопровождение_сделка',
#  'игровой',
#  'стиральный_машина',
#  'солнцево',
#  'трц',
#  'тамбур',
#  'кладовая',
#  'периметр',
#  'руб',
#  'заменить',
#  'сталинский',
#  'работа',
#  'офис_продажа',
#  'преференция_ипотека',
#  'транспортный',
#  'доехать',
#  'стеклопакеты',
#  'свет',
#  'договорённость',
#  'посудомоечный_машина',
#  'тип',
#  'ботанический_сад',
#  'ландшафтный',
#  'вкус',
#  'лобби',
#  'санузел_совместить',
#  'великолепный',
#  'отделение_банк',
#  'желание',
#  'база',
#  'постройка',
#  'эксклюзивный',
#  'га',
#  'бунинский_аллея',
#  'муниципальный',
#  'известный',
#  'четыре',
#  'зел_ный',
#  'соседний',
#  'одноподъездный_высота',
#  'иметься_ниша',
#  'пр',
#  'открыться',
#  'крупный_шоссе',
#  'домофон',
#  'качество',
#  'сады',
#  'функциональный',
#  'саларьево_румянцево',
#  'вднх',
#  'цао',
#  'старый',
#  'открытие',
#  'отопление',
#  'финансовый_гарантия',
#  'берег',
#  'двухуровневый',
#  'автотрасса_солнцево',
#  'необходимый_комфортный',
#  'несколько',
#  'сообщение',
#  'т_плая',
#  'удачный_планировка',
#  'торгово_развлекательный',
#  'сопровождение',
#  'южный',
#  'балкон_застеклить',
#  'архитектура',
#  'индивидуальный_проект',
#  'вблизи',
#  'застеклить',
#  'проживать',
#  'натяжной_потолок',
#  'поблизости',
#  'киевский_шоссе',
#  'парка',
#  'отделка_использоваться',
#  'др',
#  'провести',
#  'спорт_отдых',
#  'гостиный_столовая',
#  'группа',
#  'хранение',
#  'взять_забота',
#  'программа',
#  'гарантировать_клиент',
#  'пляж',
#  'электричка',
#  'чистый_уходить',
#  'воспользуйтесь_уникальный',
#  'круглосуточный',
#  'кладовка',
#  'сити',
#  'ветка',
#  'требоваться',
#  'вместительный',
#  'условие',
#  'лот_вт',
#  'университет',
#  'роскошный',
#  'изолированный',
#  'калужский_шоссе',
#  'почта',
#  'ходьба',
#  'широкий',
#  'ванная',
#  'развязка',
#  'царицыно',
#  'саларьево',
#  'запад',
#  'концепция',
#  'расположиться',
#  'бесплатный',
#  'доступный',
#  'жк_символ',
#  'машиноместо',
#  'грузовой',
#  'размер_млн',
#  'приватный',
#  'реновация',
#  'особенность',
#  'оплата',
#  'звоните_подробно',
#  'развлекательный',
#  'красота',
#  'предел',
#  'проживание_сдача',
#  'свежий_воздух',
#  'машино_место',
#  'большой_количество',
#  'красный',
#  'альтернатива_подобрать',
#  'переуступка',
#  'главный',
#  'дду',
#  'подарок',
#  'получать_сертификат',
#  'рамка_покупатель',
#  'звоните_менеджер',
#  'утеплить',
#  'семейный',
#  'использование',
#  'юридически_физически',
#  'идти',
#  'спланировать',
#  'деревянный',
#  'освещение',
#  'представлять',
#  'ванный',
#  'сдаваться',
#  'государственный',
#  'пентхаус',
#  'скидка_рубль',
#  'объём_реализовать',
#  'смочь_полный',
#  'сантехник',
#  'митино',
#  'юго_западный',
#  'выделить_кухонный',
#  'покупать',
#  'застройка',
#  'культура',
#  'ипотека_мат',
#  'звоните_записываться',
#  'тр',
#  'пластиковый',
#  'совмещ_нный',
#  'рубль_номер',
#  'занимать',
#  'балашиха',
#  'гардеробной',
#  'зелень',
#  'кольцо',
#  'тимирязевский',
#  'фонтан',
#  'расположенная',
#  'кутузовский_проспект',
#  'знаменитый',
#  'природный',
#  'окно_пвх',
#  'ждать',
#  'люберцы',
#  'храм',
#  'паркет',
#  'труба',
#  'музей',
#  'угловая',
#  'авторский',
#  'дет',
#  'вентиляция',
#  'приобрести',
#  'рассрочка',
#  'лесопарковый_зона',
#  'северный',
#  'душевой_кабина',
#  'новый_владелец',
#  'постирочная',
#  'установить_кондиционер',
#  'направление',
#  'химки',
#  'качественный_материал',
#  'долина_река',
#  'активный',
#  'лицей',
#  'учреждение',
#  'выбор',
#  'маршрутка',
#  'эт',
#  'переулок',
#  'ашан',
#  'деловой_центр',
#  'составлять',
#  'назначение',
#  'оперативный',
#  'архитектурный',
#  'беспокоить',
#  'массив',
#  'парк_победа',
#  'показ_договорённость',
#  'ипотека_материнский',
#  'аллея',
#  'выход_сделка',
#  'офис',
#  'духовой_шкаф',
#  'общеобразовательный_школа',
#  'плюс',
#  'момент',
#  'остекление',
#  'библиотека',
#  'остров',
#  'благоустройство',
#  'лёгкий_альтернатива',
#  'измайловский',
#  'мир',
#  'представить',
#  'рубль',
#  'смотреть',
#  'совмещенный',
#  'пешеходный',
#  'удобство',
#  'экология',
#  'культурный',
#  'архитектор',
#  'формат',
#  'крыша',
#  'обеспечить',
#  'вс_необходимый',
#  'тихо',
#  'клиент',
#  'арбат',
#  'камин',
#  'готовый_проживание',
#  'использоваться',
#  'смочь_реализовать',
#  'действовать',
#  'многоуровневый',
#  'интересный',
#  'тся',
#  'последний',
#  'иметь',
#  'квадратный_метр',
#  'трехподъездный_переменный',
#  'коломенский',
#  'сетунь',
#  'скейт_парк',
#  'гость',
#  'активный_отдых',
#  'закрыть_машина',
#  'сервис',
#  'черновой',
#  'раменки',
#  'стадион_спортивный',
#  'легко_доехать',
#  'рассказать_комн',
#  'лосиный_остров',
#  'образовательный',
#  'выдача_ключ',
#  'бутовый_варшавский',
#  'бронирование',
#  'счёт',
#  'кухонный',
#  'планироваться',
#  'проезд',
#  'форма',
#  'диван',
#  'получение',
#  'монолитный_многоподъездный',
#  'люблино',
#  'мастер_спальня',
#  'ключ_рука',
#  'шкаф_купе',
#  'кухонный_гарнитура',
#  'личный',
#  'хранение_вещь',
#  'вуз',
#  'запах',
#  'разнообразный',
#  'ставка',
#  'собственность_делать',
#  'усадьба',
#  'образ_жизнь',
#  'агент',
#  'вопрос_звоните',
#  'история',
#  'входной_металлический',
#  'проходить',
#  'шум',
#  'церковь',
#  'консьерж_сервис',
#  'выгодный_предложение',
#  'химчистка',
#  'дойти',
#  'тихий_зел',
#  'помощь_получение',
#  'встроить_техника',
#  'евро',
#  'варочный_панель',
#  'природа',
#  'уч_скидка',
#  'см',
#  'приличный_сосед',
#  'машиноместа',
#  'перекрытие',
#  'материнский_капитал',
#  'шоссе_сбв',
#  'спорткомплекс',
#  'ведущий_банк',
#  'летний',
#  'тепло',
#  'вокзал',
#  'велосипед',
#  'круглосуточный_видеонаблюдение',
#  'европланировкой',
#  'событийный_комплекс',
#  'евродвушка',
#  'владелец',
#  'технический',
#  'институт',
#  'бронь_день',
#  'непосредственно',
#  'приобретение',
#  'обратить_внимание',
#  'банковский_ячейка',
#  'вдоль',
#  'максимально',
#  'заселить',
#  'срочно',
#  'мечта',
#  'установить_сантехника',
#  'подземный_многоуровневый',
#  'стоить',
#  'ледовый_дворец',
#  'замена',
#  'серебряный_бор',
#  'эркер',
#  'технология',
#  'входить_стоимость',
#  'каток',
#  'зеленоград',
#  'система_видеонаблюдение',
#  'количество',
#  'ни',
#  'выхино',
#  'юг',
#  'мичуринский_проспект',
#  'ухоженный',
#  'пешеходный_бульвар',
#  'расположенный',
#  'россия',
#  'филёвский_парк',
#  'помочь',
#  'условие_приобретение',
#  'банк_партнёр',
#  'тихий_спокойный',
#  'интернет',
#  'программа_информация',
#  'шумоизоляция',
#  'видовой_характеристика',
#  'батарея',
#  'разместить',
#  'домодедовский',
#  'монолитный_одноподъездный',
#  'рабочий',
#  'пик',
#  'пробка',
#  'фирма',
#  'вложение',
#  'прогулочный',
#  'металлический_дверь',
#  'двухуровневый_подземный',
#  'восток',
#  'служба',
#  'дорожка',
#  'искусство',
#  'платформа',
#  'застекленный_балкон',
#  'платёж',
#  'сеть',
#  'белый',
#  'полностью_меблировать',
#  'частично',
#  'маленький',
#  'основный',
#  'солнечный',
#  'классический_стиль',
#  'сетевой_продуктовый',
#  'мытищи',
#  'оставить',
#  'колясочный',
#  'подробность_телефон',
#  'ипотека_приветствоваться',
#  'специальный',
#  'точка',
#  'туалет',
#  'выглядеть_вариант',
#  'лето',
#  'пятерочка',
#  'сегодня',
#  'оплата_наличный',
#  'произвести',
#  'третий',
#  'имя',
#  'кладовые',
#  'санузле',
#  'пл',
#  ...]
