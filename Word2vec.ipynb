# %%
#  источники - https://www.kaggle.com/code/pierremegret/gensim-word2vec-tutorial/notebook
# https://spacy.io/models/ru#ru_core_news_md

import re  # Для препроцессинга
# !pip install pandas
import pandas as pd  # Для обработки данных
from time import time  # Для определения времени операций
import spacy
from spacy.lang.ru.examples import sentences 
from collections import defaultdict  # Для частоты слов
import logging  # Настройка для gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)
# Out:
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# Requirement already satisfied: pandas in c:\users\daniel\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\daniel\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\daniel\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\daniel\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\daniel\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# Считываю файл
data = pd.read_csv('Сlean.csv')
df=data['description']
df.shape
# Out:
# (100723,)

# %%
df.head()
# Out:
# 0    Прекрасная однокомнатная квартира в доме с лиф...
# 1    Светлая, просторная комната 19 кв. метров. Отд...
# 2    Первомайская, 15 мин. пешкомТёплая уютная квар...
# 3    в шаговой доступности парк Сокольники. , Разви...
# 4    Ильинское с.Все коммуникации центральные.Кварт...
# Name: description, dtype: object

# %%
df.isnull().sum()
# Out:
# 0

# %%
# Загружаю модель
# !python -m spacy download ru_core_news_sm
# Out:
# Collecting ru-core-news-sm==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.3.0/ru_core_news_sm-3.3.0-py3-none-any.whl (15.3 MB)
#      ---------------------------------------- 15.3/15.3 MB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in c:\users\daniel\anaconda3\lib\site-packages (from ru-core-news-sm==3.3.0) (3.3.1)
# Requirement already satisfied: pymorphy2>=0.9 in c:\users\daniel\anaconda3\lib\site-packages (from ru-core-news-sm==3.3.0) (0.9.1)
# Requirement already satisfied: dawg-python>=0.7.1 in c:\users\daniel\anaconda3\lib\site-packages (from pymorphy2>=0.9->ru-core-news-sm==3.3.0) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in c:\users\daniel\anaconda3\lib\site-packages (from pymorphy2>=0.9->ru-core-news-sm==3.3.0) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in c:\users\daniel\anaconda3\lib\site-packages (from pymorphy2>=0.9->ru-core-news-sm==3.3.0) (0.6.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.28.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (8.0.15)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.7.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.10.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.0.6)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.21.5)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.3.0)
# Requirement already satisfied: jinja2 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.11.3)
# Requirement already satisfied: setuptools in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (63.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (4.64.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.0.10)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (21.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.7.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\daniel\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\daniel\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\users\daniel\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\daniel\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (4.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\daniel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\daniel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\daniel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\daniel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.3)
# Requirement already satisfied: colorama in c:\users\daniel\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.4.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\daniel\appdata\roaming\python\python39\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (8.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\daniel\anaconda3\lib\site-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\daniel\anaconda3\lib\site-packages)

# %%
nlp = spacy.load('ru_core_news_sm', disable=['ner', 'parser']) # отключение распознавания именованных объектов для повышения скорости
def cleaning(doc):
    #Лемматизируется и удаляет стоп-слова
    # doc должен быть пространственным объектом Doc
    txt = [token.lemma_ for token in doc if not token.is_stop]
    # Word2Vec использует контекстные слова для изучения векторного представления целевого слова,
    # если предложение состоит всего из одного или двух слов,
    # польза от тренинга мала, поэтому
    if len(txt) > 2:
        return ' '.join(txt)
# Out:
# INFO - 03:05:14: Loading dictionaries from c:\Users\Daniel\anaconda3\lib\site-packages\pymorphy2_dicts_ru\data
# INFO - 03:05:14: format: 2.4, revision: 417127, updated: 2020-10-11T15:05:51.070345

# %%
#Удаляю неалфавитные символы:
brief_cleaning = (re.sub("[^А-Яа-я]", ' ', str(row)).lower() for row in data['description'])

# %%
# Атрибут space .pipe() для ускорения процесса очистки:
# Подбираю оптимальное batch_size=2000, n_process=4
t = time()
txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=2000, n_process=4)]
print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 26.03 mins

# %%
#Помещаю результаты в фрейм данных, чтобы удалить недостающие значения и дубликаты:
df_clean = pd.DataFrame({'clean': txt})
df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
# Out:
# (65113, 1)

# %%
df_clean.head(20)
# Out:
#                                                 clean
# 0   прекрасный однокомнатный квартира дом лифт мус...
# 1   светлый   просторный комната     кв   метр   о...
# 2   первомайский      мина   пешкомт плая уютный к...
# 3   шаговый доступность парк сокольники     развит...
# 4   ильинский коммуникация центральный квартира хо...
# 5   продаваться срочно однокомнатный квартира ремо...
# 6   знамя октябрь пос продаваться светлый   уютный...
# 7   маяковская      мина   пешкомбаррикадная      ...
# 8   продаваться двухкомнатный квартира общий площа...
# 9   домодедово успейте купить выгодно             ...
# 10      хороший вариант инвестирование   возможнос...
# 11  обухово рппродается комната     кв ул   яковле...
# 12    срочно продажа малогабаритный     комн кварт...
# 13    дом построить   квартира сделать ремонт ингр...
# 14  продаваться    кв ра       бывший общежитие   ...
# 15  продаваться двухкомнатный квартира высокий пер...
# 16  элитный жк новый измайлово   закрытый территор...
# 17  продаваться просмотр   продаваться      доля  ...
# 18  пятницкое       мина   транспортомпросторная к...
# 19  видный квартира   отличный   состояние      ко...

# %%
df_clean.to_csv('PRE.csv',index=True)

# %%
df_clean = pd.read_csv('E:\project university\Выпускная работа\PRE.csv')

# %%
# использую пакет фраз Gensim для автоматического определения общих фраз (биграмм) из списка предложений.
from gensim.models.phrases import Phrases, Phraser

# %%
# Phrases() принимает список слов в качестве входных данных:
sent = [row.split() for row in df_clean['clean']]

# %%
# фразы из списка предложений:
phrases = Phrases(sent, min_count=30, progress_per=10000)
# Out:
# INFO - 00:00:10: collecting all words and their counts
# INFO - 00:00:10: PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO - 00:00:12: PROGRESS: at sentence #10000, processed 623358 words and 173825 word types
# INFO - 00:00:12: PROGRESS: at sentence #20000, processed 1187655 words and 273413 word types
# INFO - 00:00:13: PROGRESS: at sentence #30000, processed 1733814 words and 343709 word types
# INFO - 00:00:15: PROGRESS: at sentence #40000, processed 2866897 words and 443755 word types
# INFO - 00:00:17: PROGRESS: at sentence #50000, processed 3884567 words and 528139 word types
# INFO - 00:00:19: PROGRESS: at sentence #60000, processed 4895880 words and 598383 word types
# INFO - 00:00:19: collected 635089 token types (unigram + bigrams) from a corpus of 5313725 words and 65113 sentences
# INFO - 00:00:19: merged Phrases<635089 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>
# INFO - 00:00:19: Phrases lifecycle event {'msg': 'built Phrases<635089 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000> in 8.79s', 'datetime': '2022-11-19T00:00:19.789518', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'created'}

# %%
print(phrases)
# Out:
# Phrases<635089 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>

# %%
# Phrase() - сокращает потребление памяти Phrases(), отбросив состояние модели, которое строго не требуется для задачи обнаружения биграмм:
bigram = Phraser(phrases)
# Out:
# INFO - 00:00:19: exporting phrases from Phrases<635089 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>
# INFO - 00:00:21: FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<3862 phrases, min_count=30, threshold=10.0> from Phrases<635089 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000> in 1.99s', 'datetime': '2022-11-19T00:00:21.844445', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'created'}

# %%
#Преобразование корпуса на основе обнаруженных биграмм:
sentences = bigram[sent]

# %%
#проверка эффективности лемматизации, удаления стоп-слов и добавления биграмм.
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
len(word_freq)
# Out:
# 46478

# %%
sorted(word_freq, key=word_freq.get, reverse=True)[:10]
# Out:
# ['квартира',
#  'дом',
#  'кв',
#  'этаж',
#  'двор',
#  'район',
#  'школа',
#  'комплекс',
#  'жилой',
#  'кухня']

# %%
#использую реализацию Gensim word2vec
import multiprocessing
from gensim.models import Word2Vec

# %%
cores = multiprocessing.cpu_count() # Количество ядер на компе

# %%
#Параметры модели
w2v_model = Word2Vec(min_count=20,
                     window=2,
                     vector_size=300,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)
# Out:
# INFO - 00:00:41: Word2Vec lifecycle event {'params': 'Word2Vec(vocab=0, vector_size=300, alpha=0.03)', 'datetime': '2022-11-19T00:00:41.822829', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'created'}

# %%
# Word2Vec требует создания таблицы словарного запаса 
# (просто переварив все слова и отфильтровав уникальные слова, а также выполнив некоторые базовые подсчеты по ним):
t = time()

w2v_model.build_vocab(sentences, progress_per=10000)

print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# INFO - 00:00:43: collecting all words and their counts
# INFO - 00:00:43: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 00:00:44: PROGRESS: at sentence #10000, processed 519503 words, keeping 17344 word types
# INFO - 00:00:45: PROGRESS: at sentence #20000, processed 990655 words, keeping 23260 word types
# INFO - 00:00:46: PROGRESS: at sentence #30000, processed 1449491 words, keeping 27016 word types
# INFO - 00:00:47: PROGRESS: at sentence #40000, processed 2315237 words, keeping 34080 word types
# INFO - 00:00:48: PROGRESS: at sentence #50000, processed 3117085 words, keeping 39644 word types
# INFO - 00:00:50: PROGRESS: at sentence #60000, processed 3902562 words, keeping 44006 word types
# INFO - 00:00:50: collected 46478 word types from a corpus of 4245081 raw words and 65113 sentences
# INFO - 00:00:50: Creating a fresh vocabulary
# INFO - 00:00:50: Word2Vec lifecycle event {'msg': 'effective_min_count=20 retains 9666 unique words (20.796936184861654%% of original 46478, drops 36812)', 'datetime': '2022-11-19T00:00:50.785794', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'prepare_vocab'}
# INFO - 00:00:50: Word2Vec lifecycle event {'msg': 'effective_min_count=20 leaves 4129298 word corpus (97.27253732025372%% of original 4245081, drops 115783)', 'datetime': '2022-11-19T00:00:50.786794', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'prepare_vocab'}
# INFO - 00:00:50: deleting the raw counts dictionary of 46478 items
# INFO - 00:00:50: sample=6e-05 downsamples 862 most-common words
# INFO - 00:00:50: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1920945.4989813692 word corpus (46.5%% of prior 4129298)', 'datetime': '2022-11-19T00:00:50.908746', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'prepare_vocab'}
# INFO - 00:00:51: estimated required memory for 9666 words and 300 dimensions: 28031400 bytes
# INFO - 00:00:51: resetting layer weights
# INFO - 00:00:51: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-11-19T00:00:51.095306', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'build_vocab'}
# Time to build vocab: 0.12 mins

# %%
#Обучение модели
t = time()
w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=10, report_delay=1)
print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# INFO - 00:00:54: Word2Vec lifecycle event {'msg': 'training model with 11 workers on 9666 vocabulary and 300 features, using sg=0 hs=0 sample=6e-05 negative=20 window=2 shrink_windows=True', 'datetime': '2022-11-19T00:00:54.107455', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'train'}
# INFO - 00:00:55: EPOCH 1 - PROGRESS: at 8.25% examples, 116756 words/s, in_qsize 18, out_qsize 0
# INFO - 00:00:56: EPOCH 1 - PROGRESS: at 23.35% examples, 152571 words/s, in_qsize 21, out_qsize 0
# INFO - 00:00:57: EPOCH 1 - PROGRESS: at 40.19% examples, 172504 words/s, in_qsize 13, out_qsize 8
# INFO - 00:00:58: EPOCH 1 - PROGRESS: at 51.51% examples, 182064 words/s, in_qsize 21, out_qsize 0
# INFO - 00:00:59: EPOCH 1 - PROGRESS: at 60.42% examples, 188216 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:00: EPOCH 1 - PROGRESS: at 69.54% examples, 193857 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:01: EPOCH 1 - PROGRESS: at 78.87% examples, 196184 words/s, in_qsize 22, out_qsize 0
# INFO - 00:01:02: EPOCH 1 - PROGRESS: at 88.42% examples, 198053 words/s, in_qsize 17, out_qsize 7
# INFO - 00:01:03: worker thread finished; awaiting finish of 10 more threads
# INFO - 00:01:03: worker thread finished; awaiting finish of 9 more threads
# INFO - 00:01:03: worker thread finished; awaiting finish of 8 more threads
# INFO - 00:01:03: worker thread finished; awaiting finish of 7 more threads
# INFO - 00:01:03: worker thread finished; awaiting finish of 6 more threads
# INFO - 00:01:03: worker thread finished; awaiting finish of 5 more threads
# INFO - 00:01:03: worker thread finished; awaiting finish of 4 more threads
# INFO - 00:01:03: worker thread finished; awaiting finish of 3 more threads
# INFO - 00:01:03: worker thread finished; awaiting finish of 2 more threads
# INFO - 00:01:03: worker thread finished; awaiting finish of 1 more threads
# INFO - 00:01:03: worker thread finished; awaiting finish of 0 more threads
# INFO - 00:01:03: EPOCH - 1 : training on 4245081 raw words (1920291 effective words) took 9.0s, 213844 effective words/s
# INFO - 00:01:04: EPOCH 2 - PROGRESS: at 8.56% examples, 115970 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:05: EPOCH 2 - PROGRESS: at 23.70% examples, 161806 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:06: EPOCH 2 - PROGRESS: at 40.22% examples, 176823 words/s, in_qsize 15, out_qsize 9
# INFO - 00:01:07: EPOCH 2 - PROGRESS: at 52.57% examples, 193301 words/s, in_qsize 18, out_qsize 0
# INFO - 00:01:08: EPOCH 2 - PROGRESS: at 62.04% examples, 194950 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:09: EPOCH 2 - PROGRESS: at 71.16% examples, 199610 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:10: EPOCH 2 - PROGRESS: at 80.74% examples, 202952 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:11: EPOCH 2 - PROGRESS: at 90.43% examples, 204921 words/s, in_qsize 20, out_qsize 1
# INFO - 00:01:11: worker thread finished; awaiting finish of 10 more threads
# INFO - 00:01:11: worker thread finished; awaiting finish of 9 more threads
# INFO - 00:01:11: worker thread finished; awaiting finish of 8 more threads
# INFO - 00:01:11: worker thread finished; awaiting finish of 7 more threads
# INFO - 00:01:11: worker thread finished; awaiting finish of 6 more threads
# INFO - 00:01:11: worker thread finished; awaiting finish of 5 more threads
# INFO - 00:01:11: worker thread finished; awaiting finish of 4 more threads
# INFO - 00:01:11: worker thread finished; awaiting finish of 3 more threads
# INFO - 00:01:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 00:01:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 00:01:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 00:01:11: EPOCH - 2 : training on 4245081 raw words (1921143 effective words) took 8.8s, 218690 effective words/s
# INFO - 00:01:13: EPOCH 3 - PROGRESS: at 7.98% examples, 109084 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:14: EPOCH 3 - PROGRESS: at 22.66% examples, 157362 words/s, in_qsize 14, out_qsize 8
# INFO - 00:01:15: EPOCH 3 - PROGRESS: at 39.17% examples, 174977 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:16: EPOCH 3 - PROGRESS: at 50.98% examples, 184484 words/s, in_qsize 16, out_qsize 7
# INFO - 00:01:17: EPOCH 3 - PROGRESS: at 59.87% examples, 191304 words/s, in_qsize 20, out_qsize 1
# INFO - 00:01:18: EPOCH 3 - PROGRESS: at 69.19% examples, 197103 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:19: EPOCH 3 - PROGRESS: at 78.66% examples, 200080 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:20: EPOCH 3 - PROGRESS: at 88.22% examples, 202054 words/s, in_qsize 19, out_qsize 3
# INFO - 00:01:20: worker thread finished; awaiting finish of 10 more threads
# INFO - 00:01:20: worker thread finished; awaiting finish of 9 more threads
# INFO - 00:01:20: worker thread finished; awaiting finish of 8 more threads
# INFO - 00:01:20: worker thread finished; awaiting finish of 7 more threads
# INFO - 00:01:20: worker thread finished; awaiting finish of 6 more threads
# INFO - 00:01:20: worker thread finished; awaiting finish of 5 more threads
# INFO - 00:01:20: worker thread finished; awaiting finish of 4 more threads
# INFO - 00:01:20: worker thread finished; awaiting finish of 3 more threads
# INFO - 00:01:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 00:01:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 00:01:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 00:01:20: EPOCH - 3 : training on 4245081 raw words (1920771 effective words) took 8.9s, 216194 effective words/s
# INFO - 00:01:21: EPOCH 4 - PROGRESS: at 8.86% examples, 121082 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:22: EPOCH 4 - PROGRESS: at 26.79% examples, 180243 words/s, in_qsize 17, out_qsize 1
# INFO - 00:01:24: EPOCH 4 - PROGRESS: at 44.23% examples, 188486 words/s, in_qsize 20, out_qsize 2
# INFO - 00:01:25: EPOCH 4 - PROGRESS: at 55.59% examples, 205394 words/s, in_qsize 16, out_qsize 0
# INFO - 00:01:26: EPOCH 4 - PROGRESS: at 65.07% examples, 205449 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:27: EPOCH 4 - PROGRESS: at 75.35% examples, 212304 words/s, in_qsize 16, out_qsize 5
# INFO - 00:01:28: EPOCH 4 - PROGRESS: at 85.45% examples, 214634 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:29: worker thread finished; awaiting finish of 10 more threads
# INFO - 00:01:29: worker thread finished; awaiting finish of 9 more threads
# INFO - 00:01:29: worker thread finished; awaiting finish of 8 more threads
# INFO - 00:01:29: worker thread finished; awaiting finish of 7 more threads
# INFO - 00:01:29: worker thread finished; awaiting finish of 6 more threads
# INFO - 00:01:29: worker thread finished; awaiting finish of 5 more threads
# INFO - 00:01:29: worker thread finished; awaiting finish of 4 more threads
# INFO - 00:01:29: worker thread finished; awaiting finish of 3 more threads
# INFO - 00:01:29: worker thread finished; awaiting finish of 2 more threads
# INFO - 00:01:29: worker thread finished; awaiting finish of 1 more threads
# INFO - 00:01:29: worker thread finished; awaiting finish of 0 more threads
# INFO - 00:01:29: EPOCH - 4 : training on 4245081 raw words (1920253 effective words) took 8.4s, 228796 effective words/s
# INFO - 00:01:30: EPOCH 5 - PROGRESS: at 8.56% examples, 111153 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:31: EPOCH 5 - PROGRESS: at 27.09% examples, 174503 words/s, in_qsize 16, out_qsize 0
# INFO - 00:01:32: EPOCH 5 - PROGRESS: at 43.54% examples, 180279 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:33: EPOCH 5 - PROGRESS: at 53.28% examples, 189655 words/s, in_qsize 22, out_qsize 0
# INFO - 00:01:34: EPOCH 5 - PROGRESS: at 60.27% examples, 184349 words/s, in_qsize 22, out_qsize 0
# INFO - 00:01:35: EPOCH 5 - PROGRESS: at 71.35% examples, 196689 words/s, in_qsize 15, out_qsize 2
# INFO - 00:01:36: EPOCH 5 - PROGRESS: at 80.96% examples, 198116 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:37: EPOCH 5 - PROGRESS: at 91.08% examples, 201158 words/s, in_qsize 21, out_qsize 3
# INFO - 00:01:38: worker thread finished; awaiting finish of 10 more threads
# INFO - 00:01:38: worker thread finished; awaiting finish of 9 more threads
# INFO - 00:01:38: worker thread finished; awaiting finish of 8 more threads
# INFO - 00:01:38: worker thread finished; awaiting finish of 7 more threads
# INFO - 00:01:38: worker thread finished; awaiting finish of 6 more threads
# INFO - 00:01:38: worker thread finished; awaiting finish of 5 more threads
# INFO - 00:01:38: worker thread finished; awaiting finish of 4 more threads
# INFO - 00:01:38: worker thread finished; awaiting finish of 3 more threads
# INFO - 00:01:38: worker thread finished; awaiting finish of 2 more threads
# INFO - 00:01:38: worker thread finished; awaiting finish of 1 more threads
# INFO - 00:01:38: worker thread finished; awaiting finish of 0 more threads
# INFO - 00:01:38: EPOCH - 5 : training on 4245081 raw words (1920544 effective words) took 8.9s, 215012 effective words/s
# INFO - 00:01:39: EPOCH 6 - PROGRESS: at 8.33% examples, 113245 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:40: EPOCH 6 - PROGRESS: at 23.01% examples, 158751 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:41: EPOCH 6 - PROGRESS: at 42.21% examples, 186068 words/s, in_qsize 14, out_qsize 2
# INFO - 00:01:42: EPOCH 6 - PROGRESS: at 52.78% examples, 194646 words/s, in_qsize 18, out_qsize 0
# INFO - 00:01:43: EPOCH 6 - PROGRESS: at 61.52% examples, 198431 words/s, in_qsize 18, out_qsize 1
# INFO - 00:01:44: EPOCH 6 - PROGRESS: at 70.73% examples, 203104 words/s, in_qsize 16, out_qsize 2
# INFO - 00:01:45: EPOCH 6 - PROGRESS: at 80.55% examples, 203860 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:46: EPOCH 6 - PROGRESS: at 90.65% examples, 205106 words/s, in_qsize 17, out_qsize 10
# INFO - 00:01:46: worker thread finished; awaiting finish of 10 more threads
# INFO - 00:01:46: worker thread finished; awaiting finish of 9 more threads
# INFO - 00:01:46: worker thread finished; awaiting finish of 8 more threads
# INFO - 00:01:46: worker thread finished; awaiting finish of 7 more threads
# INFO - 00:01:46: worker thread finished; awaiting finish of 6 more threads
# INFO - 00:01:46: worker thread finished; awaiting finish of 5 more threads
# INFO - 00:01:46: worker thread finished; awaiting finish of 4 more threads
# INFO - 00:01:46: worker thread finished; awaiting finish of 3 more threads
# INFO - 00:01:46: worker thread finished; awaiting finish of 2 more threads
# INFO - 00:01:46: worker thread finished; awaiting finish of 1 more threads
# INFO - 00:01:46: worker thread finished; awaiting finish of 0 more threads
# INFO - 00:01:46: EPOCH - 6 : training on 4245081 raw words (1921275 effective words) took 8.7s, 220824 effective words/s
# INFO - 00:01:47: EPOCH 7 - PROGRESS: at 7.96% examples, 113078 words/s, in_qsize 20, out_qsize 3
# INFO - 00:01:49: EPOCH 7 - PROGRESS: at 24.38% examples, 155927 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:50: EPOCH 7 - PROGRESS: at 40.82% examples, 169941 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:51: EPOCH 7 - PROGRESS: at 51.86% examples, 175860 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:52: EPOCH 7 - PROGRESS: at 61.16% examples, 181670 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:53: EPOCH 7 - PROGRESS: at 70.29% examples, 185500 words/s, in_qsize 21, out_qsize 1
# INFO - 00:01:54: EPOCH 7 - PROGRESS: at 79.85% examples, 189458 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:55: EPOCH 7 - PROGRESS: at 89.17% examples, 191164 words/s, in_qsize 21, out_qsize 0
# INFO - 00:01:56: worker thread finished; awaiting finish of 10 more threads
# INFO - 00:01:56: worker thread finished; awaiting finish of 9 more threads
# INFO - 00:01:56: worker thread finished; awaiting finish of 8 more threads
# INFO - 00:01:56: worker thread finished; awaiting finish of 7 more threads
# INFO - 00:01:56: worker thread finished; awaiting finish of 6 more threads
# INFO - 00:01:56: worker thread finished; awaiting finish of 5 more threads
# INFO - 00:01:56: worker thread finished; awaiting finish of 4 more threads
# INFO - 00:01:56: worker thread finished; awaiting finish of 3 more threads
# INFO - 00:01:56: worker thread finished; awaiting finish of 2 more threads
# INFO - 00:01:56: worker thread finished; awaiting finish of 1 more threads
# INFO - 00:01:56: worker thread finished; awaiting finish of 0 more threads
# INFO - 00:01:56: EPOCH - 7 : training on 4245081 raw words (1919809 effective words) took 9.4s, 204839 effective words/s
# INFO - 00:01:57: EPOCH 8 - PROGRESS: at 8.85% examples, 124548 words/s, in_qsize 17, out_qsize 0
# INFO - 00:01:58: EPOCH 8 - PROGRESS: at 20.81% examples, 145370 words/s, in_qsize 15, out_qsize 8
# INFO - 00:01:59: EPOCH 8 - PROGRESS: at 36.61% examples, 161793 words/s, in_qsize 21, out_qsize 0
# INFO - 00:02:00: EPOCH 8 - PROGRESS: at 49.47% examples, 171663 words/s, in_qsize 21, out_qsize 0
# INFO - 00:02:01: EPOCH 8 - PROGRESS: at 58.43% examples, 180043 words/s, in_qsize 21, out_qsize 0
# INFO - 00:02:02: EPOCH 8 - PROGRESS: at 67.43% examples, 185066 words/s, in_qsize 21, out_qsize 0
# INFO - 00:02:03: EPOCH 8 - PROGRESS: at 76.73% examples, 189947 words/s, in_qsize 17, out_qsize 0
# INFO - 00:02:04: EPOCH 8 - PROGRESS: at 84.10% examples, 188616 words/s, in_qsize 21, out_qsize 0
# INFO - 00:02:05: EPOCH 8 - PROGRESS: at 96.32% examples, 197554 words/s, in_qsize 16, out_qsize 0
# INFO - 00:02:05: worker thread finished; awaiting finish of 10 more threads
# INFO - 00:02:05: worker thread finished; awaiting finish of 9 more threads
# INFO - 00:02:05: worker thread finished; awaiting finish of 8 more threads
# INFO - 00:02:05: worker thread finished; awaiting finish of 7 more threads
# INFO - 00:02:05: worker thread finished; awaiting finish of 6 more threads
# INFO - 00:02:05: worker thread finished; awaiting finish of 5 more threads
# INFO - 00:02:05: worker thread finished; awaiting finish of 4 more threads
# INFO - 00:02:05: worker thread finished; awaiting finish of 3 more threads
# INFO - 00:02:05: worker thread finished; awaiting finish of 2 more threads
# INFO - 00:02:05: worker thread finished; awaiting finish of 1 more threads
# INFO - 00:02:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 00:02:05: EPOCH - 8 : training on 4245081 raw words (1921062 effective words) took 9.4s, 203596 effective words/s
# INFO - 00:02:06: EPOCH 9 - PROGRESS: at 6.65% examples, 93340 words/s, in_qsize 16, out_qsize 3
# INFO - 00:02:07: EPOCH 9 - PROGRESS: at 19.28% examples, 137209 words/s, in_qsize 21, out_qsize 0
# INFO - 00:02:08: EPOCH 9 - PROGRESS: at 35.63% examples, 159916 words/s, in_qsize 22, out_qsize 0
# INFO - 00:02:09: EPOCH 9 - PROGRESS: at 47.44% examples, 162512 words/s, in_qsize 19, out_qsize 9
# INFO - 00:02:10: EPOCH 9 - PROGRESS: at 56.35% examples, 174198 words/s, in_qsize 21, out_qsize 0
# INFO - 00:02:11: EPOCH 9 - PROGRESS: at 65.27% examples, 181294 words/s, in_qsize 21, out_qsize 0
# INFO - 00:02:12: EPOCH 9 - PROGRESS: at 74.31% examples, 186391 words/s, in_qsize 22, out_qsize 0
# INFO - 00:02:14: EPOCH 9 - PROGRESS: at 83.66% examples, 190146 words/s, in_qsize 19, out_qsize 1
# INFO - 00:02:15: EPOCH 9 - PROGRESS: at 92.08% examples, 190076 words/s, in_qsize 21, out_qsize 6
# INFO - 00:02:15: worker thread finished; awaiting finish of 10 more threads
# INFO - 00:02:15: worker thread finished; awaiting finish of 9 more threads
# INFO - 00:02:15: worker thread finished; awaiting finish of 8 more threads
# INFO - 00:02:15: worker thread finished; awaiting finish of 7 more threads
# INFO - 00:02:15: worker thread finished; awaiting finish of 6 more threads
# INFO - 00:02:15: worker thread finished; awaiting finish of 5 more threads
# INFO - 00:02:15: worker thread finished; awaiting finish of 4 more threads
# INFO - 00:02:15: worker thread finished; awaiting finish of 3 more threads
# INFO - 00:02:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 00:02:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 00:02:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 00:02:15: EPOCH - 9 : training on 4245081 raw words (1921156 effective words) took 9.4s, 203365 effective words/s
# INFO - 00:02:16: EPOCH 10 - PROGRESS: at 5.77% examples, 81553 words/s, in_qsize 15, out_qsize 8
# INFO - 00:02:17: EPOCH 10 - PROGRESS: at 20.18% examples, 142237 words/s, in_qsize 21, out_qsize 0
# INFO - 00:02:18: EPOCH 10 - PROGRESS: at 36.64% examples, 161115 words/s, in_qsize 21, out_qsize 0
# INFO - 00:02:19: EPOCH 10 - PROGRESS: at 49.30% examples, 169183 words/s, in_qsize 21, out_qsize 0
# INFO - 00:02:20: EPOCH 10 - PROGRESS: at 58.01% examples, 174876 words/s, in_qsize 21, out_qsize 0
# INFO - 00:02:21: EPOCH 10 - PROGRESS: at 67.03% examples, 180380 words/s, in_qsize 21, out_qsize 0
# INFO - 00:02:22: EPOCH 10 - PROGRESS: at 76.93% examples, 184057 words/s, in_qsize 21, out_qsize 0
# INFO - 00:02:23: EPOCH 10 - PROGRESS: at 86.44% examples, 186880 words/s, in_qsize 21, out_qsize 0
# INFO - 00:02:24: worker thread finished; awaiting finish of 10 more threads
# INFO - 00:02:24: worker thread finished; awaiting finish of 9 more threads
# INFO - 00:02:24: worker thread finished; awaiting finish of 8 more threads
# INFO - 00:02:24: worker thread finished; awaiting finish of 7 more threads
# INFO - 00:02:24: worker thread finished; awaiting finish of 6 more threads
# INFO - 00:02:24: worker thread finished; awaiting finish of 5 more threads
# INFO - 00:02:24: worker thread finished; awaiting finish of 4 more threads
# INFO - 00:02:24: worker thread finished; awaiting finish of 3 more threads
# INFO - 00:02:24: worker thread finished; awaiting finish of 2 more threads
# INFO - 00:02:24: worker thread finished; awaiting finish of 1 more threads
# INFO - 00:02:24: worker thread finished; awaiting finish of 0 more threads
# INFO - 00:02:24: EPOCH - 10 : training on 4245081 raw words (1920735 effective words) took 9.5s, 201236 effective words/s
# INFO - 00:02:24: Word2Vec lifecycle event {'msg': 'training on 42450810 raw words (19207039 effective words) took 90.7s, 211778 effective words/s', 'datetime': '2022-11-19T00:02:24.803381', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'train'}
# Time to train the model: 1.51 mins

# %%
#Поскольку не планирую дальше обучать модель, вызываю init_sims(), что сделает модель намного более эффективной с точки зрения использования памяти:
w2v_model.init_sims(replace=True)
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_10716\3670000816.py:2: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#   w2v_model.init_sims(replace=True)
# WARNING - 00:02:24: destructive init_sims(replace=True) deprecated & no longer required for space-efficiency

# %%
#Наиболее похожие слова на:
w2v_model.wv.most_similar(positive=["добираться"])
# Out:
# [('быстро_добраться', 0.7362722754478455),
#  ('легко_добраться', 0.7165964841842651),
#  ('быстро_добираться', 0.7125027775764465),
#  ('добраться_точка', 0.7012991309165955),
#  ('добраться', 0.683266282081604),
#  ('доезжать', 0.6684644222259521),
#  ('выехать', 0.6568681001663208),
#  ('доехать', 0.6504923701286316),
#  ('доберетесь', 0.6495130658149719),
#  ('оказаться', 0.6255602240562439)]

# %%
#Сходство слов
w2v_model.wv.similarity("дом", 'год',)
# Out:
# 0.20000324

# %%
#Лишнее слово
w2v_model.wv.doesnt_match(['паркет', 'плитка', 'люстра'])
# Out:
# 'люстра'

# %%
#Значимость слов 
w2v_model.wv.most_similar(positive=['квартира', 'этаж'], negative=['транспорт'], topn=3)
# Out:
# [('этажность_этаж', 0.5079990029335022),
#  ('кв', 0.4985583424568176),
#  ('звезда_арбат', 0.4972324073314667)]

# %%
w2v_model.wv.index_to_key
# Out:
# ['квартира',
#  'дом',
#  'кв',
#  'этаж',
#  'двор',
#  'район',
#  'школа',
#  'комплекс',
#  'жилой',
#  'кухня',
#  'москва',
#  'ремонт',
#  'метро',
#  'два',
#  'детский_сад',
#  'парк',
#  'жк',
#  'комната',
#  'детский',
#  'окно',
#  'отделка',
#  'новый',
#  'просторный',
#  'находиться',
#  'год',
#  'минута',
#  'продаваться',
#  'корпус',
#  'хороший',
#  'сделка',
#  'шаговый_доступность',
#  'территория',
#  'станция_метро',
#  'инфраструктура',
#  'центр',
#  'магазин',
#  'студия',
#  'площадь',
#  'санузел',
#  'комнатный',
#  'квартал',
#  'продажа',
#  'площадка',
#  'свободный_продажа',
#  'взрослый_собственник',
#  'общий_площадь',
#  'отличный',
#  'минута_пешком',
#  'собственник',
#  'зона',
#  'современный',
#  'больший',
#  'место',
#  'ипотека',
#  'планировка',
#  'поликлиника',
#  'пеший_доступность',
#  'уютный',
#  'вид',
#  'лоджия',
#  'светлый',
#  'подъезд',
#  'подземный_паркинг',
#  'спальня',
#  'расположен',
#  'отдых',
#  'балкон',
#  'собственность',
#  'гостиная',
#  'окно_выходить',
#  'развитой_инфраструктура',
#  'высота_потолок',
#  'сторона',
#  'бизнес_класс',
#  'сделать',
#  'большой',
#  'машина',
#  'полный_стоимость',
#  'первый',
#  'торговый_центр',
#  'предлагаться',
#  'город',
#  'тихий',
#  'мебель',
#  'км',
#  'кредитование_первоначальный',
#  'спортивный',
#  'парковка',
#  'удобный',
#  'метр',
#  'гардеробный',
#  'кафе',
#  'аптека',
#  'транспортный_доступность',
#  'прекрасный',
#  'высокий',
#  'лифт',
#  'иметься',
#  'прода_тся',
#  'свободный',
#  'установить',
#  'станция',
#  'три',
#  'договор',
#  'проект',
#  'банк',
#  'мина',
#  'апартамент',
#  'оперативный_показ',
#  'состояние',
#  'улица',
#  'спортивный_площадка',
#  'быстрый_выход',
#  'расположены',
#  'выполнить',
#  'объект',
#  'зелёный',
#  'транспорт',
#  'т',
#  'возможный',
#  'качественный',
#  'расположена',
#  'этаж_этажный',
#  'вариант',
#  'застройщик',
#  'собственный',
#  'благоустроенный',
#  'комната_изолировать',
#  'минута_ходьба',
#  'дизайнерский',
#  'грузовой_лифт',
#  'двухкомнатный',
#  'раздельный',
#  'однокомнатный',
#  'договор_долевой',
#  'река',
#  'оборудовать',
#  'комфортный',
#  'магазины',
#  'паркинг',
#  'начало_строительство',
#  'год_оформление',
#  'жизнь',
#  'фитнес',
#  'строительство_квартал',
#  'год_окончание',
#  'кирпичный',
#  'цена',
#  'обременение',
#  'высота',
#  'просмотр',
#  'чистый',
#  'звоните',
#  'необходимый',
#  'кухня_столовая',
#  'пол',
#  'бассейн',
#  'дкп',
#  'изолировать',
#  'документ',
#  'развить_инфраструктура',
#  'внутренний',
#  'техника',
#  'первоначальный_взнос',
#  'прокшино',
#  'банк_втб',
#  'престижный',
#  'подъезд_пассажирский',
#  'чистый_подъезд',
#  'консьерж',
#  'прогулка',
#  'коридор',
#  'тёплый',
#  'тц',
#  'пруд',
#  'мина_пешком',
#  'большой_выбор',
#  'красивый',
#  'комн',
#  'ребёнок',
#  'высокий_потолок',
#  'расстояние_прямой',
#  'удобный_транспортный',
#  'банк_сбербанк',
#  'военный_ипотека',
#  'прописать',
#  'часть',
#  'ипотечный_программа',
#  'ресторан',
#  'предусмотреть',
#  'построить',
#  'звоните_подобрать',
#  'база_застройщик',
#  'взнос_срок',
#  'взнос_аккредитация',
#  'государственный_поддержка',
#  'ао_альф',
#  'год_платёж',
#  'ао_россельхозбанк',
#  'программа_срок',
#  'документ_популярный',
#  'россия_пао',
#  'участие_артикул',
#  'сосед',
#  'перепланировка',
#  'выход',
#  'пространство',
#  'ст',
#  'стена',
#  'фитнес_клуб',
#  'доступность',
#  'удобный_выезд',
#  'уникальный',
#  'дверь',
#  'км_мкад',
#  'сад',
#  'входной_группа',
#  'монолитный',
#  'отдельный',
#  'показ',
#  'взрослый',
#  'раздельный_санузел',
#  'московский_прописка',
#  'расположение',
#  'предложение',
#  'проживание',
#  'находиться_секция',
#  'плитка',
#  'торг',
#  'готовый',
#  'сдать',
#  'закрытый',
#  'ваш',
#  'холл',
#  'скидка',
#  'работать',
#  'располагаться',
#  'полный',
#  'салон_красота',
#  'исторический',
#  'уровень',
#  'год_постройка',
#  'житель',
#  'система',
#  'панорамный',
#  'подземный',
#  'входной_дверь',
#  'мебель_техника',
#  'ванный_комната',
#  'салоны_красота',
#  'прямой',
#  'монолитно_блочный',
#  'видеонаблюдение',
#  'столица',
#  'каждый',
#  'набережная',
#  'кондиционер',
#  'здание',
#  'филат_луг',
#  'возможность',
#  'панорамный_вид',
#  'установить_стеклопакет',
#  'вс',
#  'видовой',
#  'автомобиль',
#  'дизайн_проект',
#  'продам',
#  'шоссе',
#  'время',
#  'полностью',
#  'продавать',
#  'быстрый',
#  'мкад',
#  'оставаться',
#  'выходить',
#  'прихожая',
#  'шикарный',
#  'материал',
#  'множество',
#  'помещение',
#  'завести_коммуникация',
#  'дорога',
#  'кафе_ресторан',
#  'встроенная',
#  'сетевой_магазин',
#  'бытовой_техника',
#  'жк_скандинавия',
#  'московский',
#  'ул',
#  'парковочный_место',
#  'сквер',
#  'делать',
#  'панельный',
#  'экологически_чистый',
#  'лоджия_совмещенный',
#  'лес',
#  'ваш_внимание',
#  'мцд',
#  'секция',
#  'стиль',
#  'подходить_ипотека',
#  'шлагбаум',
#  'белый_ночь',
#  'включать',
#  'гостиный',
#  'остановка_общественный',
#  'банка',
#  'цена_указать',
#  'стоимость',
#  'москва_сити',
#  'компания',
#  'покупка',
#  'лесопарк',
#  'закрыть',
#  'гостевой',
#  'остановка',
#  'вход',
#  'супермаркет',
#  'огромный',
#  'повысить_тепло',
#  'потолок',
#  'функциональный_планировка',
#  'покупатель',
#  'безопасность',
#  'аренда',
#  'распашонка',
#  'выезд',
#  'кухонный_зона',
#  'жить',
#  'автобус',
#  'румянцево',
#  'общественный_транспорт',
#  'прокшино_км',
#  'альтернатива',
#  'капитальный_ремонт',
#  'охрана',
#  'продуктовый_магазин',
#  'идеальный',
#  'городской',
#  'потолки',
#  'открываться',
#  'ключ',
#  'бизнес',
#  'вода',
#  'спорт',
#  'входить',
#  'совмещенный_санузел',
#  'комфорт',
#  'переменный_этажность',
#  'комфортный_проживание',
#  'старт_продажа',
#  'полностью_готовый',
#  'рассказать',
#  'преимущество',
#  'трехкомнатная',
#  'огородить',
#  'внутри',
#  'центральный',
#  'мин',
#  'дорогой',
#  'сан_узел',
#  'гостевой_парковка',
#  'ттк',
#  'фасад',
#  'индивидуальный',
#  'позволять',
#  'прописка',
#  'второй',
#  'документ_готовый',
#  'живописный',
#  'лот',
#  'косметический_ремонт',
#  'элитный',
#  'сантехника',
#  'набережный',
#  'встроить',
#  'пять',
#  'совместить',
#  'садовый_кольцо',
#  'крупный',
#  'строиться',
#  'круглосуточный_охрана',
#  'супермаркеты',
#  'близкий',
#  'семья',
#  'окружение',
#  'доступ',
#  'безопасный',
#  'подробно_рассказать',
#  'договор_купля',
#  'капитал',
#  'оформление',
#  'садик',
#  'спальный',
#  'жильё',
#  'юридический_сопровождение',
#  'разместиться',
#  'пешком',
#  'наличный_расчёт',
#  'телефон',
#  'наличие',
#  'арт',
#  'панорамный_остекление',
#  'бульвар',
#  'юго_запад',
#  'сдача',
#  'участие',
#  'подходить',
#  'строительство',
#  'комфортный_жизнь',
#  'услуга',
#  'медицинский_центр',
#  'учёт_скидка',
#  'фото',
#  'жк_испанский',
#  'адрес',
#  'дизайн',
#  'свежий',
#  'некрасовка',
#  'пластиковый_окно',
#  'общий',
#  'являться',
#  'дополнительный',
#  'кинотеатр',
#  'спокойный',
#  'непосредственный_близость',
#  'зарегистрировать',
#  'шкаф',
#  'небольшой',
#  'въезд',
#  'купить',
#  'бронирование_день',
#  'торговый',
#  'комфорт_класс',
#  'стеклопакет',
#  'тихий_зелёный',
#  'этажность_этаж',
#  'число',
#  'гардероб',
#  'полный_юридический',
#  'клуб',
#  'огороженная_территория',
#  'социальный',
#  'клубный',
#  'вопрос',
#  'состоять',
#  'башня',
#  'гимназия',
#  'удобный_время',
#  'день',
#  'изолированный_комната',
#  'чистовой_отделка',
#  'автобусный_остановка',
#  'предлагать',
#  'недвижимость',
#  'наземный',
#  'зал',
#  'тёплый_стан',
#  'различный',
#  'премиум_класс',
#  'обеспечивать',
#  'рынок',
#  'день_просмотр',
#  'класс',
#  'площадь_ильич',
#  'игровой_площадка',
#  'кабинет',
#  'округ',
#  'полноценный',
#  'локация',
#  'премиальный',
#  'прогулочный_зона',
#  'внимание',
#  'терраса',
#  'кремль',
#  'элемент_отопление',
#  'т_плый',
#  'евроремонт',
#  'ванна',
#  'застекленная_лоджия',
#  'шумоизоляцией_установить',
#  'новый_скоростной',
#  'наземный_паркинг',
#  'итальянский',
#  'использовать',
#  'парковый_зона',
#  'тёплый_пол',
#  'угловой',
#  'выполнить_качественный',
#  'микрорайон',
#  'коммуникация',
#  'ост_тся',
#  'серия',
#  'мин_пешком',
#  'оснастить',
#  'стадион',
#  'стильный',
#  'приятный',
#  'менеджер_рассказать',
#  'придомовый_территория',
#  'открыть',
#  'ваш_старый',
#  'сдача_аренда',
#  'выбрать_новый',
#  'больница',
#  'номер_лот',
#  'воздух',
#  'решение',
#  'уходить',
#  'прямо',
#  'авто',
#  'монолитно_кирпичный',
#  'добраться',
#  'пассажирский',
#  'ландшафтный_дизайн',
#  'возле',
#  'новостройка',
#  'открытый',
#  'пол_ламинат',
#  'оформить',
#  'приватизация',
#  'жилец',
#  'человек',
#  'срок_сдача',
#  'создать',
#  'мцк',
#  'помощь_одобрение',
#  'воспользоваться_программа',
#  'информация_телефон',
#  'дерево',
#  'близость',
#  'охранять',
#  'разный',
#  'обустроить',
#  'организовать',
#  'развитой',
#  'выгодный',
#  'европейский',
#  'кладовые_помещение',
#  'этажный',
#  'учёт',
#  'мгу',
#  'специальный_условие',
#  'охранять_территория',
#  'интерьер',
#  'кухонный_гарнитур',
#  'ламинат',
#  'получить',
#  'безопасность_сделка',
#  'частный',
#  'минута_езда',
#  'саларьево_тёплый',
#  'встроить_шкаф',
#  'развить',
#  'стан_ольховая',
#  'мебель_бытовой',
#  'озеро',
#  'сбербанк',
#  'замечательный',
#  'посмотреть_фотография',
#  'объединить',
#  'требовать',
#  'содействие_получение',
#  'ночь',
#  'театр',
#  'бутовский_лесопарк',
#  'позволить',
#  'звоните_прямо',
#  'помощь',
#  'мфц',
#  'полный_сумма',
#  'холодильник',
#  'инвестиция',
#  'шумоизоляцией',
#  'линия',
#  'сопровождение_сделка',
#  'игровой',
#  'стиральный_машина',
#  'солнцево',
#  'трц',
#  'тамбур',
#  'кладовая',
#  'периметр',
#  'руб',
#  'заменить',
#  'сталинский',
#  'работа',
#  'офис_продажа',
#  'преференция_ипотека',
#  'транспортный',
#  'доехать',
#  'стеклопакеты',
#  'свет',
#  'договорённость',
#  'посудомоечный_машина',
#  'тип',
#  'ботанический_сад',
#  'ландшафтный',
#  'вкус',
#  'лобби',
#  'санузел_совместить',
#  'великолепный',
#  'отделение_банк',
#  'желание',
#  'база',
#  'постройка',
#  'эксклюзивный',
#  'га',
#  'бунинский_аллея',
#  'муниципальный',
#  'известный',
#  'четыре',
#  'зел_ный',
#  'соседний',
#  'одноподъездный_высота',
#  'иметься_ниша',
#  'пр',
#  'открыться',
#  'крупный_шоссе',
#  'домофон',
#  'качество',
#  'сады',
#  'функциональный',
#  'саларьево_румянцево',
#  'вднх',
#  'цао',
#  'старый',
#  'открытие',
#  'отопление',
#  'финансовый_гарантия',
#  'берег',
#  'двухуровневый',
#  'автотрасса_солнцево',
#  'необходимый_комфортный',
#  'несколько',
#  'сообщение',
#  'т_плая',
#  'удачный_планировка',
#  'торгово_развлекательный',
#  'сопровождение',
#  'южный',
#  'балкон_застеклить',
#  'архитектура',
#  'индивидуальный_проект',
#  'вблизи',
#  'застеклить',
#  'проживать',
#  'натяжной_потолок',
#  'поблизости',
#  'киевский_шоссе',
#  'парка',
#  'отделка_использоваться',
#  'др',
#  'провести',
#  'спорт_отдых',
#  'гостиный_столовая',
#  'группа',
#  'хранение',
#  'взять_забота',
#  'программа',
#  'гарантировать_клиент',
#  'пляж',
#  'электричка',
#  'чистый_уходить',
#  'воспользуйтесь_уникальный',
#  'круглосуточный',
#  'кладовка',
#  'сити',
#  'ветка',
#  'требоваться',
#  'вместительный',
#  'условие',
#  'лот_вт',
#  'университет',
#  'роскошный',
#  'изолированный',
#  'калужский_шоссе',
#  'почта',
#  'ходьба',
#  'широкий',
#  'ванная',
#  'развязка',
#  'царицыно',
#  'саларьево',
#  'запад',
#  'концепция',
#  'расположиться',
#  'бесплатный',
#  'доступный',
#  'жк_символ',
#  'машиноместо',
#  'грузовой',
#  'размер_млн',
#  'приватный',
#  'реновация',
#  'особенность',
#  'оплата',
#  'звоните_подробно',
#  'развлекательный',
#  'красота',
#  'предел',
#  'проживание_сдача',
#  'свежий_воздух',
#  'машино_место',
#  'большой_количество',
#  'красный',
#  'альтернатива_подобрать',
#  'переуступка',
#  'главный',
#  'дду',
#  'подарок',
#  'получать_сертификат',
#  'рамка_покупатель',
#  'звоните_менеджер',
#  'утеплить',
#  'семейный',
#  'использование',
#  'юридически_физически',
#  'идти',
#  'спланировать',
#  'деревянный',
#  'освещение',
#  'представлять',
#  'ванный',
#  'сдаваться',
#  'государственный',
#  'пентхаус',
#  'скидка_рубль',
#  'объём_реализовать',
#  'смочь_полный',
#  'сантехник',
#  'митино',
#  'юго_западный',
#  'выделить_кухонный',
#  'покупать',
#  'застройка',
#  'культура',
#  'ипотека_мат',
#  'звоните_записываться',
#  'тр',
#  'пластиковый',
#  'совмещ_нный',
#  'рубль_номер',
#  'занимать',
#  'балашиха',
#  'гардеробной',
#  'зелень',
#  'кольцо',
#  'тимирязевский',
#  'фонтан',
#  'расположенная',
#  'кутузовский_проспект',
#  'знаменитый',
#  'природный',
#  'окно_пвх',
#  'ждать',
#  'люберцы',
#  'храм',
#  'паркет',
#  'труба',
#  'музей',
#  'угловая',
#  'авторский',
#  'дет',
#  'вентиляция',
#  'приобрести',
#  'рассрочка',
#  'лесопарковый_зона',
#  'северный',
#  'душевой_кабина',
#  'новый_владелец',
#  'постирочная',
#  'установить_кондиционер',
#  'направление',
#  'химки',
#  'качественный_материал',
#  'долина_река',
#  'активный',
#  'лицей',
#  'учреждение',
#  'выбор',
#  'маршрутка',
#  'эт',
#  'переулок',
#  'ашан',
#  'деловой_центр',
#  'составлять',
#  'назначение',
#  'оперативный',
#  'архитектурный',
#  'беспокоить',
#  'массив',
#  'парк_победа',
#  'показ_договорённость',
#  'ипотека_материнский',
#  'аллея',
#  'выход_сделка',
#  'офис',
#  'духовой_шкаф',
#  'общеобразовательный_школа',
#  'плюс',
#  'момент',
#  'остекление',
#  'библиотека',
#  'остров',
#  'благоустройство',
#  'лёгкий_альтернатива',
#  'измайловский',
#  'мир',
#  'представить',
#  'рубль',
#  'смотреть',
#  'совмещенный',
#  'пешеходный',
#  'удобство',
#  'экология',
#  'культурный',
#  'архитектор',
#  'формат',
#  'крыша',
#  'обеспечить',
#  'вс_необходимый',
#  'тихо',
#  'клиент',
#  'арбат',
#  'камин',
#  'готовый_проживание',
#  'использоваться',
#  'смочь_реализовать',
#  'действовать',
#  'многоуровневый',
#  'интересный',
#  'тся',
#  'последний',
#  'иметь',
#  'квадратный_метр',
#  'трехподъездный_переменный',
#  'коломенский',
#  'сетунь',
#  'скейт_парк',
#  'гость',
#  'активный_отдых',
#  'закрыть_машина',
#  'сервис',
#  'черновой',
#  'раменки',
#  'стадион_спортивный',
#  'легко_доехать',
#  'рассказать_комн',
#  'лосиный_остров',
#  'образовательный',
#  'выдача_ключ',
#  'бутовый_варшавский',
#  'бронирование',
#  'счёт',
#  'кухонный',
#  'планироваться',
#  'проезд',
#  'форма',
#  'диван',
#  'получение',
#  'монолитный_многоподъездный',
#  'люблино',
#  'мастер_спальня',
#  'ключ_рука',
#  'шкаф_купе',
#  'кухонный_гарнитура',
#  'личный',
#  'хранение_вещь',
#  'вуз',
#  'запах',
#  'разнообразный',
#  'ставка',
#  'собственность_делать',
#  'усадьба',
#  'образ_жизнь',
#  'агент',
#  'вопрос_звоните',
#  'история',
#  'входной_металлический',
#  'проходить',
#  'шум',
#  'церковь',
#  'консьерж_сервис',
#  'выгодный_предложение',
#  'химчистка',
#  'дойти',
#  'тихий_зел',
#  'помощь_получение',
#  'встроить_техника',
#  'евро',
#  'варочный_панель',
#  'природа',
#  'уч_скидка',
#  'см',
#  'приличный_сосед',
#  'машиноместа',
#  'перекрытие',
#  'материнский_капитал',
#  'шоссе_сбв',
#  'спорткомплекс',
#  'ведущий_банк',
#  'летний',
#  'тепло',
#  'вокзал',
#  'велосипед',
#  'круглосуточный_видеонаблюдение',
#  'европланировкой',
#  'событийный_комплекс',
#  'евродвушка',
#  'владелец',
#  'технический',
#  'институт',
#  'бронь_день',
#  'непосредственно',
#  'приобретение',
#  'обратить_внимание',
#  'банковский_ячейка',
#  'вдоль',
#  'максимально',
#  'заселить',
#  'срочно',
#  'мечта',
#  'установить_сантехника',
#  'подземный_многоуровневый',
#  'стоить',
#  'ледовый_дворец',
#  'замена',
#  'серебряный_бор',
#  'эркер',
#  'технология',
#  'входить_стоимость',
#  'каток',
#  'зеленоград',
#  'система_видеонаблюдение',
#  'количество',
#  'ни',
#  'выхино',
#  'юг',
#  'мичуринский_проспект',
#  'ухоженный',
#  'пешеходный_бульвар',
#  'расположенный',
#  'россия',
#  'филёвский_парк',
#  'помочь',
#  'условие_приобретение',
#  'банк_партнёр',
#  'тихий_спокойный',
#  'интернет',
#  'программа_информация',
#  'шумоизоляция',
#  'видовой_характеристика',
#  'батарея',
#  'разместить',
#  'домодедовский',
#  'монолитный_одноподъездный',
#  'рабочий',
#  'пик',
#  'пробка',
#  'фирма',
#  'вложение',
#  'прогулочный',
#  'металлический_дверь',
#  'двухуровневый_подземный',
#  'восток',
#  'служба',
#  'дорожка',
#  'искусство',
#  'платформа',
#  'застекленный_балкон',
#  'платёж',
#  'сеть',
#  'белый',
#  'полностью_меблировать',
#  'частично',
#  'маленький',
#  'основный',
#  'солнечный',
#  'классический_стиль',
#  'сетевой_продуктовый',
#  'мытищи',
#  'оставить',
#  'колясочный',
#  'подробность_телефон',
#  'ипотека_приветствоваться',
#  'специальный',
#  'точка',
#  'туалет',
#  'выглядеть_вариант',
#  'лето',
#  'пятерочка',
#  'сегодня',
#  'оплата_наличный',
#  'произвести',
#  'третий',
#  'имя',
#  'кладовые',
#  'санузле',
#  'пл',
#  ...]
